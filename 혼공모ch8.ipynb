# %% [markdown]
# <a href="https://colab.research.google.com/github/dididi0913/deeplearningstd/blob/main/%ED%98%BC%EA%B3%B5%EB%AA%A8ch8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow  import keras
keras.layers.Conv2D(10, kernel_size=(3,3), activation='relu',padding='same', strides=1)
# Out:
# <Conv2D name=conv2d_1, built=False>

# %%
keras.layers.MaxPooling2D(2)
# Out:
# <MaxPooling2D name=max_pooling2d, built=True>

# %%
keras.layers.MaxPooling2D(2,strides=2, padding='valid')
# Out:
# <MaxPooling2D name=max_pooling2d_1, built=True>

# %% [markdown]
# 확인문제
#
# *   1번문제: 정답3번
# *   2번문제: 47 8 42 41 12 38 43 14 46
# *   3번문제:,,
